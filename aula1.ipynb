# %% [markdown]
# ## SEMANA EDA( Exploratory Data Analysis)

# %% [markdown]
# ## Análise Exploratória de Dados

# %% [markdown]
# ## Problema

# %% [markdown]
# - Uma escola necessita trabalhar com filmes em seuplanejamento pedagógico.
# - Precisa visualizar as notas de diversos filmes em suas diversas categorias.
# - Os filmes devem atravessar gerações.A escola trabalha desde a creche até o nível superior.

# %% [markdown]
# ## Ambientação

# %% [markdown]
# - Usaremos a linguagem Python (multi, tip.din, ident, bibli, poo)

# %%
# Crie um ambiente virtual

# %%
# Alô mundo para não perder o costume
"""
Crie um "Hello EDA"

"""

mensagem = "Hello Semana EDA"
print(f"{mensagem}")
msg_input = input("digite a palavra da semana")
print(msg_input)
# Out:
# Hello Semana EDA
# d sbfgh

# %% [markdown]
# ## Competências

# %% [markdown]
# - Importar pandas
# - Ler dados csv
# - Organizar pastas VS CODE
# - Renomear colunas
# - Contar os dados
# - Melhorar a visualização das infromações
# - Criar gráficos pandas (plot), matplotlib, Seaborn

# %% [markdown]
# ## Ferramentas e Recursos

# %% [markdown]
# - Jupyter ( Visual Code, Anaconda, Jupyter, Google Colab, Azure e AWS)
# - Kaggle (Risco de Crédito): IA ML Superv. Regressão
# - TrendView
# - MovieLens (opção de 100 mil)
# - Python - lambda (Paradigma Funcional)
# - Bibliotecas (NumPy, Pandas, Matplotlib e Seaborn)
# - Gráficos (barras, pizza, dispersão,historiograma, boxplot etc.)
# - Youtube (População, Amostra, Frequência, Mediana, Quartis)
# - Estatísca Descritiva (frequências e medidas)

# %% [markdown]
# ## Tipos de Variáveis

# %% [markdown]
# #### Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Pandas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### MySQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Estaticas descritivas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Importação do Pandas

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %% [markdown]
# Importação do DataSet

# %%
df = pd.read_csv('datasets/ratings.csv')

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
df['movieId']
# Out:
# 0              1
# 1              3
# 2              6
# 3             47
# 4             50
#            ...
# 100831    166534
# 100832    168248
# 100833    168250
# 100834    168252
# 100835    170875
# Name: movieId, Length: 100836, dtype: int64

# %% [markdown]
# Variavel quantidade Discreta (estatisco) Variavel Inteira (programador)

# %%
df['rating']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: rating, Length: 100836, dtype: float64

# %%
df.columns = ['usuario_id','filme_id','avaliacao','tempo']

# %%
df.columns
# Out:
# Index(['usuario_id', 'filme_id', 'avaliacao', 'tempo'], dtype='object')

# %% [markdown]
# ### Mostrando uma coluna

# %%
df['avaliacao']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %% [markdown]
# ### Mostrando uma coluna (+sintática)

# %%
df.avaliacao
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: avaliacao, Length: 100836, dtype: float64

# %% [markdown]
# ## O lider 360° solicitou a conatgem de notas x qtdefilmes

# %%
df.avaliacao.value_counts()
# Out:
# avaliacao
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
df.avaliacao.mean()
# Out:
# np.float64(3.501556983616962)

# %%
df.head(25)
# Out:
#     usuario_id  filme_id  avaliacao      tempo
# 0            1         1        4.0  964982703
# 1            1         3        4.0  964981247
# 2            1         6        4.0  964982224
# 3            1        47        5.0  964983815
# 4            1        50        5.0  964982931
# 5            1        70        3.0  964982400
# 6            1       101        5.0  964980868
# 7            1       110        4.0  964982176
# 8            1       151        5.0  964984041
# 9            1       157        5.0  964984100
# 10           1       163        5.0  964983650
# 11           1       216        5.0  964981208
# 12           1       223        3.0  964980985
# 13           1       231        5.0  964981179
# 14           1       235        4.0  964980908
# 15           1       260        5.0  964981680
# 16           1       296        3.0  964982967
# 17           1       316        3.0  964982310
# 18           1       333        5.0  964981179
# 19           1       349        4.0  964982563
# 20           1       356        4.0  964980962
# 21           1       362        5.0  964982588
# 22           1       367        4.0  964981710
# 23           1       423        3.0  964982363
# 24           1       441        4.0  964980868

# %% [markdown]
# ### Buscando Valores unicos

# %%
df.avaliacao.unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %% [markdown]
# ### Contando histórias com histogramas

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
df.avaliacao.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: avaliacao, dtype: float64

# %% [markdown]
# ### Média, Mediana (Q2 - segundo quartil), Soma

# %%
print(f"Imprimindo a média: {df.avaliacao.mean()}")
# Out:
# Imprimindo a média: 3.501556983616962

# %%
print(f"Imprimindo o 2° Quartil (mediana/metade): {df.avaliacao.median()}")
# Out:
# Imprimindo o 2° Quartil (mediana/metade): 3.5

# %%
print(f"Imprimindo a soma: {df.avaliacao.sum()}")
# Out:
# Imprimindo a soma: 353083.0

# %% [markdown]
# ### População

# %% [markdown]
# - Todos os alunos do SENAI DF
# - Uma amostra dos alunos do SENAI DF (Taguatinga)

# %% [markdown]
# ## Boxplot

# %%
! pip install seaborn
# Out:
# ^C
# Requirement already satisfied: seaborn in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ead\documents\gabrielle\semanaeda\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %% [markdown]
# ### Data Driven (Netflix,Spotfy)

# %% [markdown]
# #### Importando o Seaborn

# %%
import seaborn as sns

# %%
notas = df.avaliacao

# %%
sns.boxplot(notas)
# Out:
# <Axes: ylabel='avaliacao'>

# %%
sns.boxplot(x=notas)
# Out:
# <Axes: xlabel='avaliacao'>

# %% [markdown]
# #### Conclusão :
#
# - Que tipos de informações podemos extrair?
# - Conseguimos descobrir a metade(mediana)
# - Conseguimos demonstrar usnado gráficos (histograma e bloxplot)
# - Ler dados e apresentar esses dados .

# %% [markdown]
# #### Após o intervalo (exercícios) - Marvin (agora é só você!)
#
#
# - Ex.1 - Ler o dataset chamado movies.csv

# %%
# Tacar codigo aqui
df = pd.read_csv('datasets/movies.csv')
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %% [markdown]
# - Ex.2 - Mostrar os 5 primeiros

# %%
# Tacar codigo aqui
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# - Ex.3 - Renomear as colunas para ['filme_id', 'titulo','generos']

# %%
# Tacar codigo aqui
df.columns = ['filme_id','titulo','generos']

# %% [markdown]
# - Ex.4 - Mostrar os cinco primeiros com colunas renomeadas

# %%
# Tacar codigo aqui
df.head()
# Out:
#    filme_id                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# - Desafio - Mostrar as cinco primeiras avaliações apenas do Toy Story com colunas renomeadas. Dica : Use df.query()

# %%
# Tacar codigo aqui

df.query("filme_id==1").head()
# Out:
#    filme_id            titulo                                      generos
# 0         1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
